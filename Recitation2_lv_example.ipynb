# %%
import roadrunner
rr = roadrunner.RoadRunner("LV_sbml.xml")

# %%
rr.model.keys()
# Out:
# ['S1',
#  'S2',
#  '[S1]',
#  '[S2]',
#  'cell',
#  'alpha',
#  'beta',
#  'delta',
#  'gamma',
#  'Bunny',
#  'Wolf',
#  'R1',
#  'R2',
#  'R3',
#  'init([S1])',
#  'init([S2])',
#  'init(S1)',
#  'init(S2)',
#  "S1'",
#  "S2'"]

# %%
rr.reset()
result = rr.simulate(0, 140, 100)
rr.plot();

# %%
rr.reset();
print(rr['init([S1])'])
rr['init([S1])'] = 20
rr['init([S2])'] = 5
result = rr.simulate(0, 140, 100)
rr.plot();
# Out:
# 10.0
